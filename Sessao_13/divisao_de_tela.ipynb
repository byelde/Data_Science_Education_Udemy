# %% [markdown]
# # Divisão de tela (SubPlot)
# ### Possibilita mostrar vários elementos (subplots) em uma única figura

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('trees.csv')
data.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %% [markdown]
# ## Relação entre as variávies

# %%
# Girth <=> Volume
plt.scatter(x=data.Girth, y=data.Volume)

# %%
# Height <=> Volume
plt.scatter(x=data.Height, y=data.Volume)

# %%
# Height <=> Girth
plt.scatter(x=data.Height, y=data.Girth)

# %%
# Frequencia do volume
display(np.histogram(data.Volume))
display('=-'*35)

plt.hist(data.Volume)
# Out:
# (array([ 5, 10,  4,  4,  2,  0,  4,  1,  0,  1], dtype=int64),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]))
# '=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-'
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Unir os elementos em uma única figura

# %%
plt.figure(1)
# Molde: plt.subplot(qtde.linha, qtde.coluna, posição)

plt.subplot(2,2,1)
plt.scatter(x=data.Girth, y=data.Volume)

plt.subplot(2,2,2)
plt.scatter(x=data.Height, y=data.Volume)

plt.subplot(2,2,3)
plt.scatter(x=data.Height, y=data.Girth)

plt.subplot(2,2,4)
plt.hist(data.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)
